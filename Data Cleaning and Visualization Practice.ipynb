# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\viswa\\Data Science and ML\\Datasets\\DS Datasets\\nc-est2015-agesex-res.csv")

# %%
df.isnull().sum()
# Out:
# SEX                  0
# AGE                  0
# CENSUS2010POP        0
# ESTIMATESBASE2010    0
# POPESTIMATE2010      0
# POPESTIMATE2011      0
# POPESTIMATE2012      0
# POPESTIMATE2013      0
# POPESTIMATE2014      0
# POPESTIMATE2015      0
# dtype: int64

# %%
df
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# 0      0    0        3944153            3944160          3951330
# 1      0    1        3978070            3978090          3957888
# 2      0    2        4096929            4096939          4090862
# 3      0    3        4119040            4119051          4111920
# 4      0    4        4063170            4063186          4077551
# ..   ...  ...            ...                ...              ...
# 301    2   97          53582              53605            54118
# 302    2   98          36641              36675            37532
# 303    2   99          26193              26214            26074
# 304    2  100          44202              44246            45058
# 305    2  999      156964212          156969328        157258820
#
#      POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# 0            3963087          3926540          3931141          3949775
# ...

# %%
plt.plot(df["AGE"])

# %%
df["AGE"].value_counts().tail(50)
# Out:
# 50     3
# 13     3
# 23     3
# 22     3
# 21     3
# 20     3
# 19     3
# 18     3
# 17     3
# 16     3
# 15     3
# 14     3
# 12     3
# 49     3
# 11     3
# 10     3
# 9      3
# 8      3
# 7      3
# 6      3
# 5      3
# 4      3
# 3      3
# 2      3
# 24     3
# 25     3
# 26     3
# 27     3
# 48     3
# 47     3
# 46     3
# 45     3
# 44     3
# 43     3
# 42     3
# 41     3
# 40     3
# 39     3
# 38     3
# 37     3
# 36     3
# 35     3
# 34     3
# 33     3
# 32     3
# 31     3
# 30     3
# 29     3
# 28     3
# 999    3
# Name: AGE, dtype: int64

# %%
df.shape
# Out:
# (306, 10)

# %%
df.describe()
# Out:
#               SEX         AGE  CENSUS2010POP  ESTIMATESBASE2010  \
# count  306.000000  306.000000   3.060000e+02       3.060000e+02
# mean     1.000000   59.303922   4.035889e+06       4.036054e+06
# std      0.817834   98.060950   2.140881e+07       2.140968e+07
# min      0.000000    0.000000   6.073000e+03       6.075000e+03
# 25%      0.000000   25.000000   9.987065e+05       9.987415e+05
# 50%      1.000000   50.500000   2.045286e+06       2.045342e+06
# 75%      2.000000   76.000000   2.304370e+06       2.304525e+06
# max      2.000000  999.000000   3.087455e+08       3.087581e+08
#
#        POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# count     3.060000e+02     3.060000e+02     3.060000e+02     3.060000e+02
# mean      4.043750e+06     4.074756e+06     4.105917e+06     4.136306e+06
# std       2.145038e+07     2.161430e+07     2.177900e+07     2.193965e+07
# min       6.104000e+03     6.606000e+03     7.459000e+03     8.159000e+03
# ...

# %%
df.rename(columns={"POPESTIMATE2014":"2014","POPESTIMATE2010":"2010"},inplace=True)

# %%
df
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010       2010  POPESTIMATE2011  \
# 0      0    0        3944153            3944160    3951330          3963087
# 1      0    1        3978070            3978090    3957888          3966551
# 2      0    2        4096929            4096939    4090862          3971565
# 3      0    3        4119040            4119051    4111920          4102470
# 4      0    4        4063170            4063186    4077551          4122294
# ..   ...  ...            ...                ...        ...              ...
# 301    2   97          53582              53605      54118            57159
# 302    2   98          36641              36675      37532            40116
# 303    2   99          26193              26214      26074            27030
# 304    2  100          44202              44246      45058            47556
# 305    2  999      156964212          156969328  157258820        158427085
#
# ...

# %%
df.head(10)
# Out:
#    SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 0    0    0        3944153            3944160  3951330          3963087
# 1    0    1        3978070            3978090  3957888          3966551
# 2    0    2        4096929            4096939  4090862          3971565
# 3    0    3        4119040            4119051  4111920          4102470
# 4    0    4        4063170            4063186  4077551          4122294
# 5    0    5        4056858            4056872  4064653          4087709
# 6    0    6        4066381            4066412  4073013          4074993
# 7    0    7        4030579            4030594  4043046          4083225
# 8    0    8        4046486            4046497  4025604          4053203
# 9    0    9        4148353            4148369  4125415          4035710
#
#    POPESTIMATE2012  POPESTIMATE2013     2014  POPESTIMATE2015
# 0          3926540          3931141  3949775          3978038
# ...

# %%
df.iloc[[14,21],:]
# Out:
#     SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 14    0   14        4165982            4166059  4145614          4131501
# 21    0   21        4354294            4354603  4387956          4596166
#
#     POPESTIMATE2012  POPESTIMATE2013     2014  POPESTIMATE2015
# 14          4135460          4148966  4233839          4185386
# 21          4632892          4580130  4492373          4456790

# %%
df["change"]=df["POPESTIMATE2012"].diff()

# %%
df["Percentage_Change"]=df["POPESTIMATE2012"].pct_change()*100

# %%
df
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010       2010  POPESTIMATE2011  \
# 0      0    0        3944153            3944160    3951330          3963087
# 1      0    1        3978070            3978090    3957888          3966551
# 2      0    2        4096929            4096939    4090862          3971565
# 3      0    3        4119040            4119051    4111920          4102470
# 4      0    4        4063170            4063186    4077551          4122294
# ..   ...  ...            ...                ...        ...              ...
# 301    2   97          53582              53605      54118            57159
# 302    2   98          36641              36675      37532            40116
# 303    2   99          26193              26214      26074            27030
# 304    2  100          44202              44246      45058            47556
# 305    2  999      156964212          156969328  157258820        158427085
#
# ...

# %% [markdown]
# This will create two new columns in the DataFrame: change, which is the difference between the close and open prices, and percent_change, which is the percentage change in the close price relative to the previous row. Note that the first row of the percent_change column will be NaN, since there is no previous row to compare it to.

# %%
df=pd.read_csv("C:\\Users\\viswa\\Data Science and ML\\Datasets\\DS Datasets\\nc-est2015-agesex-res.csv")
df=df[66:71]

# %%
for c in df.columns:
    df[c+"change"]=df[c].diff()
df
# Out:
#     SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# 66    0   66        2639141            2639209          2621335
# 67    0   67        2649365            2649426          2693707
# 68    0   68        2323672            2323736          2359816
# 69    0   69        2142324            2142381          2167830
# 70    0   70        2043121            2043178          2062577
#
#     POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# 66          2646364          2644042          3531521          3347060
# 67          2586302          2612002          2609390          3485241
# 68          2654106          2548669          2574501          2572359
# 69          2321925          2612071          2507744          2534295
# 70          2129707          2282127          2566440          2465438
#
#     POPESTIMATE2015  SEXchange  AGEchange  CENSUS2010POPchange  \
# 66          3344134        NaN        NaN                  NaN
# ...

# %%
plt.plot(df["AGE"],df["POPESTIMATE2010"],label="2010")
plt.plot(df["AGE"],df["POPESTIMATE2011"],label="2011")
plt.plot(df["AGE"],df["POPESTIMATE2012"],label="2012")
plt.plot(df["AGE"],df["POPESTIMATE2013"],label="2013")
plt.plot(df["AGE"],df["POPESTIMATE2014"],label="2014")
plt.plot(df["AGE"],df["POPESTIMATE2015"],label="2015")
plt.legend()
plt.show()

# %%
df=pd.read_csv("C:\\Users\\viswa\\Data Science and ML\\Datasets\\DS Datasets\\nc-est2015-agesex-res.csv")
d = df[df["AGE"]==0]
d=d[0:2]
d
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# 0      0    0        3944153            3944160          3951330
# 102    1    0        2014276            2014278          2018420
#
#      POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# 0            3963087          3926540          3931141          3949775
# 102          2028427          2007717          2009528          2020326
#
#      POPESTIMATE2015
# 0            3978038
# 102          2035134

# %%
d=d.iloc[0:,4:]
d
# Out:
#      POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# 0            3951330          3963087          3926540          3931141
# 102          2018420          2028427          2007717          2009528
#
#      POPESTIMATE2014  POPESTIMATE2015
# 0            3949775          3978038
# 102          2020326          2035134

# %%
d.iloc[0]=d.iloc[0]/d.iloc[1]

# %%
d=d.iloc[0,:]
d
# Out:
# POPESTIMATE2010    1.957635
# POPESTIMATE2011    1.953774
# POPESTIMATE2012    1.955724
# POPESTIMATE2013    1.956251
# POPESTIMATE2014    1.955019
# POPESTIMATE2015    1.954681
# Name: 0, dtype: float64

# %%
f=d.index
for i in range(0,6):
    if d[i]>1:
        print(f[i][11:])
# Out:
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015

# %%
df=pd.read_csv("C:\\Users\\viswa\\Data Science and ML\\Datasets\\DS Datasets\\nc-est2015-agesex-res.csv")
df
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# 0      0    0        3944153            3944160          3951330
# 1      0    1        3978070            3978090          3957888
# 2      0    2        4096929            4096939          4090862
# 3      0    3        4119040            4119051          4111920
# 4      0    4        4063170            4063186          4077551
# ..   ...  ...            ...                ...              ...
# 301    2   97          53582              53605            54118
# 302    2   98          36641              36675            37532
# 303    2   99          26193              26214            26074
# 304    2  100          44202              44246            45058
# 305    2  999      156964212          156969328        157258820
#
#      POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# 0            3963087          3926540          3931141          3949775
# ...

# %%
df=df[df["AGE"]<999]
df=df[df["SEX"]<2]

# %%
age=df["AGE"]
age
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 198     96
# 199     97
# 200     98
# 201     99
# 202    100
# Name: AGE, Length: 202, dtype: int64

# %%
d=df.groupby(["AGE","SEX"]).sum()

# %%
d
# Out:
#          CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# AGE SEX
# 0   0          3944153            3944160          3951330          3963087
#     1          2014276            2014278          2018420          2028427
# 1   0          3978070            3978090          3957888          3966551
#     1          2030853            2030861          2020332          2025522
# 2   0          4096929            4096939          4090862          3971565
# ...                ...                ...              ...              ...
# 98  1             9259               9263             9505            10554
# 99  0            32266              32289            32178            33636
#     1             6073               6075             6104             6606
# 100 0            53364              53412            54410            57702
#     1             9162               9166             9352            10146
#
# ...

# %%
for i in range(0,len(age),2):
    for j in range(2,8):
        d.iloc[(i,j)]=d.iloc[(i,j)]/d.iloc[(i+1,j)]
d
# Out:
#          CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# AGE SEX
# 0   0          3944153            3944160     1.957635e+00     1.953774e+00
#     1          2014276            2014278     2.018420e+06     2.028427e+06
# 1   0          3978070            3978090     1.959029e+00     1.958286e+00
#     1          2030853            2030861     2.020332e+06     2.025522e+06
# 2   0          4096929            4096939     1.958583e+00     1.959358e+00
# ...                ...                ...              ...              ...
# 98  1             9259               9263     9.505000e+03     1.055400e+04
# 99  0            32266              32289     5.271625e+00     5.091735e+00
#     1             6073               6075     6.104000e+03     6.606000e+03
# 100 0            53364              53412     5.818007e+00     5.687167e+00
#     1             9162               9166     9.352000e+03     1.014600e+04
#
# ...

# %%
a=d.index
v=[]
for i in a:
    v.append(i[1])
v=np.array(v)
d["SEXX"]=v

# %%
d
# Out:
#          CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# AGE SEX
# 0   0          3944153            3944160     1.957635e+00     1.953774e+00
#     1          2014276            2014278     2.018420e+06     2.028427e+06
# 1   0          3978070            3978090     1.959029e+00     1.958286e+00
#     1          2030853            2030861     2.020332e+06     2.025522e+06
# 2   0          4096929            4096939     1.958583e+00     1.959358e+00
# ...                ...                ...              ...              ...
# 98  1             9259               9263     9.505000e+03     1.055400e+04
# 99  0            32266              32289     5.271625e+00     5.091735e+00
#     1             6073               6075     6.104000e+03     6.606000e+03
# 100 0            53364              53412     5.818007e+00     5.687167e+00
#     1             9162               9166     9.352000e+03     1.014600e+04
#
# ...

# %%
d=d[d["SEXX"]<1]
d
# Out:
#          CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# AGE SEX
# 0   0          3944153            3944160         1.957635         1.953774
# 1   0          3978070            3978090         1.959029         1.958286
# 2   0          4096929            4096939         1.958583         1.959358
# 3   0          4119040            4119051         1.956872         1.958878
# 4   0          4063170            4063186         1.956305         1.957104
# ...                ...                ...              ...              ...
# 96  0            95223              95288         4.411997         4.254485
# 97  0            68138              68168         4.662809         4.546944
# 98  0            45900              45938         4.948659         4.801023
# 99  0            32266              32289         5.271625         5.091735
# 100 0            53364              53412         5.818007         5.687167
#
# ...

# %%
a=np.unique(age)
d["AGEE"]=a
d
# Out:
# C:\Users\viswa\AppData\Local\Temp\ipykernel_6548\237546701.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d["AGEE"]=a
#          CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# AGE SEX
# 0   0          3944153            3944160         1.957635         1.953774
# 1   0          3978070            3978090         1.959029         1.958286
# 2   0          4096929            4096939         1.958583         1.959358
# 3   0          4119040            4119051         1.956872         1.958878
# 4   0          4063170            4063186         1.956305         1.957104
# ...                ...                ...              ...              ...
# ...

# %%
plt.plot(d["AGEE"],d["POPESTIMATE2010"],label="2010")
plt.plot(d["AGEE"],d["POPESTIMATE2011"],label="2011")
plt.plot(d["AGEE"],d["POPESTIMATE2012"],label="2012")
plt.plot(d["AGEE"],d["POPESTIMATE2013"],label="2013")
plt.plot(d["AGEE"],d["POPESTIMATE2014"],label="2014")
plt.plot(d["AGEE"],d["POPESTIMATE2015"],label="2015")
plt.legend()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
d=pd.read_csv("C:\\Users\\viswa\\Data Science and ML\\Datasets\\DS Datasets\\educ_inc.csv")

# %%
d
# Out:
#              Year        Age  Gender          Educational Attainment  \
# 0     1/1/08 0:00   00 to 17    Male  College, less than 4-yr degree
# 1     1/1/08 0:00   00 to 17  Female  College, less than 4-yr degree
# 2     1/1/08 0:00  65 to 80+    Male  College, less than 4-yr degree
# 3     1/1/08 0:00  65 to 80+  Female          No high school diploma
# 4     1/1/08 0:00   00 to 17  Female          No high school diploma
# ...           ...        ...     ...                             ...
# 1021  1/1/14 0:00   18 to 64  Female       High school or equivalent
# 1022  1/1/14 0:00   18 to 64    Male     Bachelor's degree or higher
# 1023  1/1/14 0:00   18 to 64  Female          No high school diploma
# 1024  1/1/14 0:00   18 to 64  Female     Bachelor's degree or higher
# 1025  1/1/14 0:00   18 to 64    Male     Bachelor's degree or higher
#
#           Personal Income  Population Count
# 0     C: 10,000 to 14,999              1304
# 1       B: 5,000 to 9,999              1565
# ...

# %%
d["Year"]=pd.to_datetime(d["Year"])

# %%
d
# Out:
#            Year        Age  Gender          Educational Attainment  \
# 0    2008-01-01   00 to 17    Male  College, less than 4-yr degree
# 1    2008-01-01   00 to 17  Female  College, less than 4-yr degree
# 2    2008-01-01  65 to 80+    Male  College, less than 4-yr degree
# 3    2008-01-01  65 to 80+  Female          No high school diploma
# 4    2008-01-01   00 to 17  Female          No high school diploma
# ...         ...        ...     ...                             ...
# 1021 2014-01-01   18 to 64  Female       High school or equivalent
# 1022 2014-01-01   18 to 64    Male     Bachelor's degree or higher
# 1023 2014-01-01   18 to 64  Female          No high school diploma
# 1024 2014-01-01   18 to 64  Female     Bachelor's degree or higher
# 1025 2014-01-01   18 to 64    Male     Bachelor's degree or higher
#
#           Personal Income  Population Count
# 0     C: 10,000 to 14,999              1304
# 1       B: 5,000 to 9,999              1565
# ...

# %%
d.isnull().sum()
# Out:
# Year                      0
# Age                       0
# Gender                    0
# Educational Attainment    0
# Personal Income           0
# Population Count          0
# dtype: int64

# %%
d.groupby(by="Educational Attainment").sum()
# Out:
# C:\Users\viswa\AppData\Local\Temp\ipykernel_20904\266517739.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   d.groupby(by="Educational Attainment").sum()
#                                 Population Count
# Educational Attainment
# Bachelor's degree or higher             54617676
# College, less than 4-yr degree          52137494
# High school or equivalent               42942926
# No high school diploma                  40668871

# %%
d.groupby(by = 'Educational Attainment')['Population Count'].sum()
# Out:
# Educational Attainment
# Bachelor's degree or higher       54617676
# College, less than 4-yr degree    52137494
# High school or equivalent         42942926
# No high school diploma            40668871
# Name: Population Count, dtype: int64

# %%
d
# Out:
#            Year        Age  Gender          Educational Attainment  \
# 0    2008-01-01   00 to 17    Male  College, less than 4-yr degree
# 1    2008-01-01   00 to 17  Female  College, less than 4-yr degree
# 2    2008-01-01  65 to 80+    Male  College, less than 4-yr degree
# 3    2008-01-01  65 to 80+  Female          No high school diploma
# 4    2008-01-01   00 to 17  Female          No high school diploma
# ...         ...        ...     ...                             ...
# 1021 2014-01-01   18 to 64  Female       High school or equivalent
# 1022 2014-01-01   18 to 64    Male     Bachelor's degree or higher
# 1023 2014-01-01   18 to 64  Female          No high school diploma
# 1024 2014-01-01   18 to 64  Female     Bachelor's degree or higher
# 1025 2014-01-01   18 to 64    Male     Bachelor's degree or higher
#
#           Personal Income  Population Count
# 0     C: 10,000 to 14,999              1304
# 1       B: 5,000 to 9,999              1565
# ...

# %%
d["Age"].value_counts()
# Out:
# 18 to 64     448
# 65 to 80+    444
# 00 to 17     134
# Name: Age, dtype: int64

# %%
d["Educational Attainment"].value_counts()
# Out:
# No high school diploma            287
# College, less than 4-yr degree    258
# High school or equivalent         250
# Bachelor's degree or higher       231
# Name: Educational Attainment, dtype: int64

# %%
d=d.replace("00 to 17","C")

# %%
d=d.replace("65 to 80+","A")
d=d.replace("18 to 64","A")

# %%
d
# Out:
#            Year Age  Gender          Educational Attainment  \
# 0    2008-01-01   C    Male  College, less than 4-yr degree
# 1    2008-01-01   C  Female  College, less than 4-yr degree
# 2    2008-01-01   A    Male  College, less than 4-yr degree
# 3    2008-01-01   A  Female          No high school diploma
# 4    2008-01-01   C  Female          No high school diploma
# ...         ...  ..     ...                             ...
# 1021 2014-01-01   A  Female       High school or equivalent
# 1022 2014-01-01   A    Male     Bachelor's degree or higher
# 1023 2014-01-01   A  Female          No high school diploma
# 1024 2014-01-01   A  Female     Bachelor's degree or higher
# 1025 2014-01-01   A    Male     Bachelor's degree or higher
#
#           Personal Income  Population Count
# 0     C: 10,000 to 14,999              1304
# 1       B: 5,000 to 9,999              1565
# 2           A: 0 to 4,999              1923
# 3      H: 75,000 and over              1981
# ...

# %%
d=d[d["Age"]=='A']

# %%
c=d.groupby(by=["Age","Educational Attainment"]).size()

# %%
c
# Out:
# Age  Educational Attainment
# A    Bachelor's degree or higher       224
#      College, less than 4-yr degree    224
#      High school or equivalent         223
#      No high school diploma            221
# dtype: int64

# %%
a=[]
for i in range(0,4):
    a.append(c[i]/(c[0]+c[1]+c[2]+c[3]))
a
# Out:
# [0.25112107623318386, 0.25112107623318386, 0.25, 0.24775784753363228]

# %%
a=np.array(a)
a
# Out:
# array([0.25112108, 0.25112108, 0.25      , 0.24775785])

# %%
ed=["BDH","CL 4","HS","NHSD"]

# %%
plt.bar(ed,a,width=0.4)
# Out:
# <BarContainer object of 4 artists>

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(a,labels=ed)
plt.show()

# %%
d
# Out:
#            Year Age  Gender          Educational Attainment  \
# 2    2008-01-01   A    Male  College, less than 4-yr degree
# 3    2008-01-01   A  Female          No high school diploma
# 9    2008-01-01   A  Female          No high school diploma
# 11   2008-01-01   A    Male          No high school diploma
# 16   2008-01-01   A  Female          No high school diploma
# ...         ...  ..     ...                             ...
# 1021 2014-01-01   A  Female       High school or equivalent
# 1022 2014-01-01   A    Male     Bachelor's degree or higher
# 1023 2014-01-01   A  Female          No high school diploma
# 1024 2014-01-01   A  Female     Bachelor's degree or higher
# 1025 2014-01-01   A    Male     Bachelor's degree or higher
#
#           Personal Income  Population Count
# 2           A: 0 to 4,999              1923
# 3      H: 75,000 and over              1981
# 9      H: 75,000 and over              4233
# 11     H: 75,000 and over              5801
# ...

# %%
d=d[d["Gender"]=="Male"]

# %%
d
# Out:
#            Year Age Gender          Educational Attainment  \
# 2    2008-01-01   A   Male  College, less than 4-yr degree
# 11   2008-01-01   A   Male          No high school diploma
# 17   2008-01-01   A   Male       High school or equivalent
# 19   2008-01-01   A   Male       High school or equivalent
# 24   2008-01-01   A   Male          No high school diploma
# ...         ...  ..    ...                             ...
# 1012 2014-01-01   A   Male  College, less than 4-yr degree
# 1013 2014-01-01   A   Male       High school or equivalent
# 1016 2014-01-01   A   Male  College, less than 4-yr degree
# 1022 2014-01-01   A   Male     Bachelor's degree or higher
# 1025 2014-01-01   A   Male     Bachelor's degree or higher
#
#           Personal Income  Population Count
# 2           A: 0 to 4,999              1923
# 11     H: 75,000 and over              5801
# 17          A: 0 to 4,999              8278
# 19     H: 75,000 and over              8527
# ...

# %%
d.mean()
# Out:
# C:\Users\viswa\AppData\Local\Temp\ipykernel_20904\1214089992.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   d.mean()
# C:\Users\viswa\AppData\Local\Temp\ipykernel_20904\1214089992.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   d.mean()
# Population Count    204202.733184
# dtype: float64

# %%
d.skew()
# Out:
# C:\Users\viswa\AppData\Local\Temp\ipykernel_20904\2440410602.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   d.skew()
# Population Count    2.934033
# dtype: float64

# %%
d.kurt()
# Out:
# C:\Users\viswa\AppData\Local\Temp\ipykernel_20904\4061438475.py:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   d.kurt()
# Population Count    13.092889
# dtype: float64

# %%
d.median()
# Out:
# C:\Users\viswa\AppData\Local\Temp\ipykernel_20904\3286961719.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   d.median()
# C:\Users\viswa\AppData\Local\Temp\ipykernel_20904\3286961719.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   d.median()
# Population Count    106749.5
# dtype: float64

# %%
d
# Out:
#            Year Age Gender          Educational Attainment  \
# 2    2008-01-01   A   Male  College, less than 4-yr degree
# 11   2008-01-01   A   Male          No high school diploma
# 17   2008-01-01   A   Male       High school or equivalent
# 19   2008-01-01   A   Male       High school or equivalent
# 24   2008-01-01   A   Male          No high school diploma
# ...         ...  ..    ...                             ...
# 1012 2014-01-01   A   Male  College, less than 4-yr degree
# 1013 2014-01-01   A   Male       High school or equivalent
# 1016 2014-01-01   A   Male  College, less than 4-yr degree
# 1022 2014-01-01   A   Male     Bachelor's degree or higher
# 1025 2014-01-01   A   Male     Bachelor's degree or higher
#
#           Personal Income  Population Count
# 2           A: 0 to 4,999              1923
# 11     H: 75,000 and over              5801
# 17          A: 0 to 4,999              8278
# 19     H: 75,000 and over              8527
# ...

# %%
d=d.sort_values("Population Count")

# %%
d
# Out:
#            Year Age Gender          Educational Attainment  \
# 448  2011-01-01   A   Male          No high school diploma
# 2    2008-01-01   A   Male  College, less than 4-yr degree
# 886  2014-01-01   A   Male          No high school diploma
# 157  2009-01-01   A   Male          No high school diploma
# 745  2013-01-01   A   Male  College, less than 4-yr degree
# ...         ...  ..    ...                             ...
# 144  2008-01-01   A   Male     Bachelor's degree or higher
# 293  2009-01-01   A   Male     Bachelor's degree or higher
# 736  2012-01-01   A   Male     Bachelor's degree or higher
# 1025 2014-01-01   A   Male     Bachelor's degree or higher
# 880  2013-01-01   A   Male     Bachelor's degree or higher
#
#          Personal Income  Population Count
# 448   H: 75,000 and over              1686
# 2          A: 0 to 4,999              1923
# 886   H: 75,000 and over              2153
# 157   H: 75,000 and over              2915
# ...

# %%
import pandas as pd

# Sample dataset (replace this with your actual dataset)
data = pd.DataFrame({
    'Age': [25, 30, 35, 40, 45],
    'Income': [50000, 60000, 75000, 80000, 90000],
    'Score': [85, 88, 90, 92, 95]
})

# 1. Count the number of non-null values in each column
count = data.count()
print("Count:")
print(count)

# 2. Calculate the mean (average) of numeric columns
mean = data.mean()
print("\nMean:")
print(mean)

# 3. Calculate the median of numeric columns
median = data.median()
print("\nMedian:")
print(median)

# 4. Calculate the standard deviation of numeric columns
std = data.std()
print("\nStandard Deviation:")
print(std)

# 5. Find the minimum and maximum values in numeric columns
min_val = data.min()
max_val = data.max()
print("\nMinimum values:")
print(min_val)
print("\nMaximum values:")
print(max_val)

# 6. Calculate the sum of values in numeric columns
sum_values = data.sum()
print("\nSum:")
print(sum_values)

# 7. Calculate the variance of numeric columns
variance = data.var()
print("\nVariance:")
print(variance)

# 8. Compute the correlation between columns
correlation = data.corr()
print("\nCorrelation:")
print(correlation)

# 9. Calculate specific percentiles of numeric columns
percentiles = data.quantile([0.25, 0.5, 0.75])
print("\nPercentiles:")
print(percentiles)

# 10. Get a summary of descriptive statistics for all numeric columns
summary = data.describe()
print("\nSummary:")
print(summary)

# 11. Count the unique values in a column
value_counts = data['Age'].value_counts()
print("\nValue Counts:")
print(value_counts)

# 12. Calculate the skewness and kurtosis of numeric columns
skewness = data.skew()
kurtosis = data.kurt()
print("\nSkewness:")
print(skewness)
print("\nKurtosis:")
print(kurtosis)
# Out:
# Count:
# Age       5
# Income    5
# Score     5
# dtype: int64
#
# Mean:
# Age          35.0
# Income    71000.0
# Score        90.0
# dtype: float64
#
# Median:
# Age          35.0
# Income    75000.0
# Score        90.0
# dtype: float64
#
# Standard Deviation:
# Age           7.905694
# Income    15968.719423
# Score         3.807887
# dtype: float64
#
# Minimum values:
# Age          25
# Income    50000
# Score        85
# dtype: int64
#
# Maximum values:
# Age          45
# Income    90000
# Score        95
# dtype: int64
#
# Sum:
# Age          175
# Income    355000
# Score        450
# dtype: int64
#
# Variance:
# Age              62.5
# Income    255000000.0
# Score            14.5
# dtype: float64
#
# Correlation:
#              Age    Income     Score
# Age     1.000000  0.990148  0.996546
# Income  0.990148  1.000000  0.986727
# Score   0.996546  0.986727  1.000000
#
# Percentiles:
#        Age   Income  Score
# 0.25  30.0  60000.0   88.0
# 0.50  35.0  75000.0   90.0
# ...

# %%
import pandas as pd

# Sample DataFrame with multiple columns
data = pd.DataFrame({
    'Date': ['2022-01-01', '2022-01-01', '2022-01-02', '2022-01-02'],
    'Category': ['A', 'B', 'A', 'B'],
    'Value1': [10, 20, 15, 25],
    'Value2': [30, 40, 35, 45]
})

# Pivot the DataFrame based on 'Date' and 'Category' columns, with multiple value columns
pivot_data = data.pivot(index='Date', columns='Category', values=['Value1', 'Value2'])

# Display the pivoted DataFrame
print(pivot_data)
# Out:
#            Value1     Value2
# Category        A   B      A   B
# Date
# 2022-01-01     10  20     30  40
# 2022-01-02     15  25     35  45

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some sample data
data = np.random.randn(100)

# Sort the data for the quantile plot
data.sort()

# Create a figure with two subplots (box plot and quantile plot)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Box Plot
ax1.boxplot(data)
ax1.set_xlabel('Data')
ax1.set_ylabel('Values')
ax1.set_title('Box Plot')

# Quantile Plot
quantiles = np.arange(0, 1.1, 0.1)
quantile_values = np.percentile(data, quantiles * 100)
ax2.plot(quantiles, quantile_values, marker='o', linestyle='--')
ax2.set_xlabel('Quantiles')
ax2.set_ylabel('Values')
ax2.set_title('Quantile Plot')
ax2.grid(True)

plt.tight_layout()
plt.show()
