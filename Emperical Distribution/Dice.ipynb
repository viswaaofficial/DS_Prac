# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
a=[]

# %%
for i in range(1000):
    a.append(np.random.choice(6)+1)

# %%
df=pd.DataFrame(a)

# %%
plt.hist(df,bins=6)
# Out:
# (array([15580111., 15580953., 15580488., 15584801., 15579265., 15591814.]),
#  array([1.        , 1.83333333, 2.66666667, 3.5       , 4.33333333,
#         5.16666667, 6.        ]),
#  <BarContainer object of 6 artists>)
