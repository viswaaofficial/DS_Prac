# %% [markdown]
# <center> <u><h1> DATA SAMPLING </h1></u> </center>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

d1 = pd.read_csv("C:\\Users\\viswa\\Data Science and ML\\Datasets\\StudentsPerformance.csv")
d1.shape
# Out:
# (1000, 8)

# %% [markdown]
# <h1> Populations and Samples </h1>
# <h2> SAMPLING TECHNIQUES </h2>

# %% [markdown]
# ### Simple Random Sampling

# %%
d1.sample(n=3)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 771    male        group D           bachelor's degree      standard
# 874  female        group C           bachelor's degree  free/reduced
# 669    male        group D          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 771                    none          75             73             74
# 874                    none          43             62             61
# 669               completed          81             72             77

# %%
d1.sample(n=3,random_state=42)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 521  female        group C          associate's degree      standard
# 737  female        group B                some college  free/reduced
# 740    male        group D           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 521                    none          91             86             84
# 737               completed          53             66             73
# 740                    none          80             73             72

# %%
d1.sample(frac=0.1,replace=True,random_state=5)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 867    male        group B          associate's degree      standard
# 206    male        group E           bachelor's degree      standard
# 701  female        group B            some high school      standard
# 998  female        group D                some college      standard
# 118  female        group D            some high school      standard
# ..      ...            ...                         ...           ...
# 418    male        group D                some college      standard
# 685  female        group E             master's degree      standard
# 699    male        group C                 high school  free/reduced
# 408  female        group D                 high school  free/reduced
# 397  female        group C          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ## Stratified Sampling

# %%
import pandas as pd
import seaborn as sns
d2 = pd.read_csv("C:\\Users\\viswa\\Data Science and ML\\Datasets\\StudentsPerformance.csv")
d2.shape
# Out:
# (1000, 8)

# %%
sns.histplot(d2["race/ethnicity"])
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='Count'>

# %%
d2.groupby("race/ethnicity",group_keys=False).apply(lambda
x:x.sample(min(len(x),3)))
#here x is nothing but grouping first and then from that taking 3 instances randomly
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 546  female        group A            some high school      standard
# 830  female        group A                some college  free/reduced
# 444    male        group A            some high school  free/reduced
# 858    male        group B                 high school      standard
# 724    male        group B                some college      standard
# 815    male        group B            some high school      standard
# 387  female        group C          associate's degree  free/reduced
# 239    male        group C          associate's degree      standard
# 887    male        group C                 high school  free/reduced
# 583  female        group D          associate's degree      standard
# 883    male        group D           bachelor's degree  free/reduced
# 659    male        group D          associate's degree      standard
# 206    male        group E           bachelor's degree      standard
# ...

# %% [markdown]
# ## Systematic Sampling

# %%
d3 = pd.read_csv("C:\\Users\\viswa\\Data Science and ML\\Datasets\\StudentsPerformance.csv")
d3.shape
# Out:
# (1000, 8)

# %%
step_size = 6
d3.iloc[::step_size]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 6    female        group B                some college      standard
# 12   female        group B                 high school      standard
# 18     male        group C             master's degree  free/reduced
# 24     male        group D           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# 972  female        group A                 high school  free/reduced
# 978    male        group D                 high school      standard
# 984  female        group C            some high school      standard
# 990    male        group E                 high school  free/reduced
# 996    male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
indices = np.arange(random.randint(1,30), len(d3), step=step_size)
d3.iloc[indices]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 13     male        group A                some college      standard
# 19   female        group C          associate's degree  free/reduced
# 25     male        group A             master's degree  free/reduced
# 31   female        group B                some college      standard
# 37   female        group D            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 973  female        group D                some college  free/reduced
# 979  female        group C          associate's degree      standard
# 985    male        group A                 high school      standard
# 991  female        group B            some high school      standard
# 997  female        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...
